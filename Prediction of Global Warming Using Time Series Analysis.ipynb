# %%
import pandas as pd

# %%
whether_df=pd.read_excel(r"C:\Users\tejas\OneDrive\Desktop\power bi data\whether_data.xlsx")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 whether_df=pd.read_excel(r"C:\Users\tejas\OneDrive\Desktop\power bi data\whether_data.xlsx")
#
# NameError: name 'pd' is not defined

# %%
whether_df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        7.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08         31.0        2.0   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0     NaN

# %%
whether_df.shape
# Out:
# (9, 4)

# %%
whether_df.value_counts("temperature")
# Out:
# temperature
# 32.0    2
# 28.0    1
# 31.0    1
# 34.0    1
# 40.0    1
# Name: count, dtype: int64

# %%
whether_df.value_counts("windspeed")
# Out:
# windspeed
# 7.0     2
# 2.0     1
# 6.0     1
# 8.0     1
# 12.0    1
# Name: count, dtype: int64

# %%
whether_df.value_counts("event")
# Out:
# event
# Rain      2
# Sunny     2
# Cloudy    1
# Snow      1
# Name: count, dtype: int64

# %%
whether_df.sort_values("event",ascending=False)
# Out:
#          day  temperature  windspeed   event
# 1 2017-01-04          NaN        7.0   Sunny
# 5 2017-01-08         31.0        2.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 0 2017-01-01         32.0        6.0    Rain
# 4 2017-01-07         32.0        NaN    Rain
# 7 2017-01-10         34.0        8.0  Cloudy
# 3 2017-01-06          NaN        7.0     NaN
# 6 2017-01-09          NaN        NaN     NaN
# 8 2017-01-11         40.0       12.0     NaN

# %%
whether_df.sort_values("temperature",ascending=False)
# Out:
#          day  temperature  windspeed   event
# 8 2017-01-11         40.0       12.0     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 0 2017-01-01         32.0        6.0    Rain
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08         31.0        2.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 1 2017-01-04          NaN        7.0   Sunny
# 3 2017-01-06          NaN        7.0     NaN
# 6 2017-01-09          NaN        NaN     NaN

# %%
whether_df.sort_values("windspeed",ascending=False)
# Out:
#          day  temperature  windspeed   event
# 8 2017-01-11         40.0       12.0     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 1 2017-01-04          NaN        7.0   Sunny
# 3 2017-01-06          NaN        7.0     NaN
# 0 2017-01-01         32.0        6.0    Rain
# 5 2017-01-08         31.0        2.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 4 2017-01-07         32.0        NaN    Rain
# 6 2017-01-09          NaN        NaN     NaN

# %%
whether_df.head()
# Out:
#          day  temperature  windspeed  event
# 0 2017-01-01         32.0        6.0   Rain
# 1 2017-01-04          NaN        7.0  Sunny
# 2 2017-01-05         28.0        NaN   Snow
# 3 2017-01-06          NaN        7.0    NaN
# 4 2017-01-07         32.0        NaN   Rain

# %%
whether_df.tail()
# Out:
#          day  temperature  windspeed   event
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08         31.0        2.0   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0     NaN

# %%
whether_df.head(3)
# Out:
#          day  temperature  windspeed  event
# 0 2017-01-01         32.0        6.0   Rain
# 1 2017-01-04          NaN        7.0  Sunny
# 2 2017-01-05         28.0        NaN   Snow

# %%
whether_df.tail(3)
# Out:
#          day  temperature  windspeed   event
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0     NaN

# %%
whether_df=pd.DataFrame(whether_df,index=[8,7,6,5,4,3,2,1])

# %%
whether_df
# Out:
#          day  temperature  windspeed   event
# 8 2017-01-11         40.0       12.0     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 6 2017-01-09          NaN        NaN     NaN
# 5 2017-01-08         31.0        2.0   Sunny
# 4 2017-01-07         32.0        NaN    Rain
# 3 2017-01-06          NaN        7.0     NaN
# 2 2017-01-05         28.0        NaN    Snow
# 1 2017-01-04          NaN        7.0   Sunny

# %%
whether_df.loc[0:4,"day":"temperature"]
# Out:
#          day  temperature
# 0 2017-01-01         32.0
# 1 2017-01-04          NaN
# 2 2017-01-05         28.0
# 3 2017-01-06          NaN
# 4 2017-01-07         32.0

# %%
whether_df.loc[0:7,"day":"temperature"]
# Out:
#          day  temperature
# 0 2017-01-01         32.0
# 1 2017-01-04          NaN
# 2 2017-01-05         28.0
# 3 2017-01-06          NaN
# 4 2017-01-07         32.0
# 5 2017-01-08         31.0
# 6 2017-01-09          NaN
# 7 2017-01-10         34.0

# %%
whether_df.loc[1:5,"day":"temperature"]
# Out:
#          day  temperature
# 1 2017-01-04          NaN
# 2 2017-01-05         28.0
# 3 2017-01-06          NaN
# 4 2017-01-07         32.0
# 5 2017-01-08         31.0

# %%
whether_df.loc[4:8:2,"day":"windspeed"]
# Out:
#          day  temperature  windspeed
# 4 2017-01-07         32.0        NaN
# 6 2017-01-09          NaN        NaN
# 8 2017-01-11         40.0       12.0

# %%
whether_df.loc[4:8:3,"day":"event"]
# Out:
#          day  temperature  windspeed   event
# 4 2017-01-07         32.0        NaN    Rain
# 7 2017-01-10         34.0        8.0  Cloudy

# %%
whether_df.loc[4:8:1,"day":"windspeed"]
# Out:
#          day  temperature  windspeed
# 4 2017-01-07         32.0        NaN
# 5 2017-01-08         31.0        2.0
# 6 2017-01-09          NaN        NaN
# 7 2017-01-10         34.0        8.0
# 8 2017-01-11         40.0       12.0

# %%
whether_df.loc[0:8:2,"day":"windspeed"]
# Out:
#          day  temperature  windspeed
# 0 2017-01-01         32.0        6.0
# 2 2017-01-05         28.0        NaN
# 4 2017-01-07         32.0        NaN
# 6 2017-01-09          NaN        NaN
# 8 2017-01-11         40.0       12.0

# %%
whether_df.loc[0:8:1,"day":"event"]
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        7.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08         31.0        2.0   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0     NaN

# %%
whether_df.iloc[0:5,0:2]
# Out:
#          day  temperature
# 0 2017-01-01         32.0
# 1 2017-01-04          NaN
# 2 2017-01-05         28.0
# 3 2017-01-06          NaN
# 4 2017-01-07         32.0

# %%
whether_df.iloc[0:6,0:4]
# Out:
#          day  temperature  windspeed  event
# 0 2017-01-01         32.0        6.0   Rain
# 1 2017-01-04          NaN        7.0  Sunny
# 2 2017-01-05         28.0        NaN   Snow
# 3 2017-01-06          NaN        7.0    NaN
# 4 2017-01-07         32.0        NaN   Rain
# 5 2017-01-08         31.0        2.0  Sunny

# %%
whether_df.iloc[3:6,0:4]
# Out:
#          day  temperature  windspeed  event
# 3 2017-01-06          NaN        7.0    NaN
# 4 2017-01-07         32.0        NaN   Rain
# 5 2017-01-08         31.0        2.0  Sunny

# %%
whether_df.isnull()
# Out:
#      day  temperature  windspeed  event
# 0  False        False      False  False
# 1  False         True      False  False
# 2  False        False       True  False
# 3  False         True      False   True
# 4  False        False       True  False
# 5  False        False      False  False
# 6  False         True       True   True
# 7  False        False      False  False
# 8  False        False      False   True

# %%
whether_df.isnull().sum()
# Out:
# day            0
# temperature    3
# windspeed      3
# event          3
# dtype: int64

# %%
whether_df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        7.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08         31.0        2.0   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0     NaN

# %%
whether_df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# dtype: bool

# %%
whether_df.duplicated().sum()
# Out:
# 0

# %%
whether_df.duplicated("temperature").sum()
# Out:
# 3

# %%
whether_df.duplicated("event").sum()
# Out:
# 4

# %%
whether_df.duplicated("windspeed").sum()
# Out:
# 3

# %%
whether_df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        7.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08         31.0        2.0   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0     NaN

# %%
whether_df["temperature"].mean()
# Out:
# 32.833333333333336

# %%
whether_df["windspeed"].median()
# Out:
# 7.0

# %%
whether_df["temperature"] = whether_df["temperature"].fillna(whether_df["temperature"].mean())

# %%
whether_df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01    32.000000        6.0    Rain
# 1 2017-01-04    32.833333        7.0   Sunny
# 2 2017-01-05    28.000000        NaN    Snow
# 3 2017-01-06    32.833333        7.0     NaN
# 4 2017-01-07    32.000000        NaN    Rain
# 5 2017-01-08    31.000000        2.0   Sunny
# 6 2017-01-09    32.833333        NaN     NaN
# 7 2017-01-10    34.000000        8.0  Cloudy
# 8 2017-01-11    40.000000       12.0     NaN

# %%
whether_df["windspeed"] = whether_df["windspeed"].fillna(whether_df["windspeed"].median())

# %%
whether_df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01    32.000000        6.0    Rain
# 1 2017-01-04    32.833333        7.0   Sunny
# 2 2017-01-05    28.000000        7.0    Snow
# 3 2017-01-06    32.833333        7.0     NaN
# 4 2017-01-07    32.000000        7.0    Rain
# 5 2017-01-08    31.000000        2.0   Sunny
# 6 2017-01-09    32.833333        7.0     NaN
# 7 2017-01-10    34.000000        8.0  Cloudy
# 8 2017-01-11    40.000000       12.0     NaN

# %%
whether_df["event"] = whether_df["event"].fillna("no event")

# %%
whether_df
# Out:
#          day  temperature  windspeed     event
# 0 2017-01-01    32.000000        6.0      Rain
# 1 2017-01-04    32.833333        7.0     Sunny
# 2 2017-01-05    28.000000        7.0      Snow
# 3 2017-01-06    32.833333        7.0  no event
# 4 2017-01-07    32.000000        7.0      Rain
# 5 2017-01-08    31.000000        2.0     Sunny
# 6 2017-01-09    32.833333        7.0  no event
# 7 2017-01-10    34.000000        8.0    Cloudy
# 8 2017-01-11    40.000000       12.0  no event

# %%
whether_df["temperature"] = whether_df["temperature"].fillna(whether_df["temperature"].mean())

# %%
whether_df["windspeed"] = whether_df["windspeed"].fillna(whether_df["windspeed"].median())

# %%
whether_df["event"] = whether_df["event"].fillna("no event")

# %%
whether_df
# Out:
#          day  temperature  windspeed     event
# 0 2017-01-01    32.000000        6.0      Rain
# 1 2017-01-04    32.833333        7.0     Sunny
# 2 2017-01-05    28.000000        7.0      Snow
# 3 2017-01-06    32.833333        7.0  no event
# 4 2017-01-07    32.000000        7.0      Rain
# 5 2017-01-08    31.000000        2.0     Sunny
# 6 2017-01-09    32.833333        7.0  no event
# 7 2017-01-10    34.000000        8.0    Cloudy
# 8 2017-01-11    40.000000       12.0  no event

# %%
whether_df.isnull().sum()
# Out:
# day            0
# temperature    0
# windspeed      0
# event          0
# dtype: int64

# %%
whether_df.duplicated("temperature").sum()
# Out:
# 3

# %%
whether_df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        7.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08         31.0        2.0   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0     NaN

# %%
whether_df.dropna(inplace=True)

# %%
whether_df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 5 2017-01-08         31.0        2.0   Sunny
# 7 2017-01-10         34.0        8.0  Cloudy

# %%
whether_df.corr(numeric_only=True)
# Out:
#              temperature  windspeed
# temperature     1.000000   0.928571
# windspeed       0.928571   1.000000

# %%
whether_df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        7.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08         31.0        2.0   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0     NaN

# %%
whether_df.dtypes
# Out:
# day            datetime64[ns]
# temperature           float64
# windspeed             float64
# event                  object
# dtype: object

# %%
whether_df.describe()
# Out:
#                        day  temperature  windspeed
# count                    9     6.000000   6.000000
# mean   2017-01-06 18:40:00    32.833333   7.000000
# min    2017-01-01 00:00:00    28.000000   2.000000
# 25%    2017-01-05 00:00:00    31.250000   6.250000
# 50%    2017-01-07 00:00:00    32.000000   7.000000
# 75%    2017-01-09 00:00:00    33.500000   7.750000
# max    2017-01-11 00:00:00    40.000000  12.000000
# std                    NaN     4.020779   3.224903

# %%
whether_df=pd.read_excel(r"C:\Users\tejas\OneDrive\Desktop\power bi data\whether_data.xlsx")

# %%
whether_df.plot(kind="scatter",x="temperature",y="windspeed")
# Out:
# <Axes: xlabel='temperature', ylabel='windspeed'>

# %%
whether_df.plot(kind="bar",x="event",y="temperature")
# Out:
# <Axes: xlabel='event'>

# %%
whether_df.plot(kind="bar",x="windspeed",y="temperature")
# Out:
# <Axes: xlabel='windspeed'>

# %%
import pandas as pd

# %%
whether_df=pd.read_excel(r"C:\Users\tejas\OneDrive\Desktop\power bi data\whether_data.xlsx")

# %%
whether_df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        7.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08         31.0        2.0   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0     NaN

# %%
whether_df.plot(kind="bar",x="event",y="windspeed")
# Out:
# <Axes: xlabel='event'>
