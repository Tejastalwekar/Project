# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import skew, kurtosis

# %%
path=r"C:\Users\tejas\OneDrive\Desktop\power bi data\power bi\winequality-red.csv"

# %%
with open(path, 'r', encoding='utf-8') as f:
    lines = f.readlines()

cleaned_lines = [line.strip().replace('\t', '').replace('"', '') for line in lines]

clean_path = r"C:\Users\tejas\OneDrive\Desktop\power bi data\power bi\winequality-red.csv"
with open(clean_path, 'w', encoding='utf-8') as f:
    for line in cleaned_lines:
        f.write(line + '\n')

df_wine = pd.read_csv(clean_path, sep=';')

print(df_wine.head())
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# **data is set in proper format**

# %% [markdown]
# **Task 1 : Task 1: Basic Distribution of Numerical Variable ,Use histograms to display the distribution of the following numerical features: fixed_acidity ,volatile_acidity , residual_sugar , chlorides , free_sulfur_dioxide ,total_sulfur_dioxide , density , ph , sulphates , and alcohol .**

# %%
plt.hist(df_wine['fixed acidity'], bins=30, color='darkgreen', edgecolor='black')
plt.xlabel('fixed acidity')
plt.title('Distributiion of Fixed acidity')
plt.show()

# %%
plt.hist(df_wine['volatile acidity'], bins=30, color='yellow', edgecolor='black')
plt.xlabel('volatile acidity')
plt.title('Distributiion of Volatile acidity')
plt.show()

# %%
plt.hist(df_wine['residual sugar'], bins=30, color='blue', edgecolor='black')
plt.xlabel('residual sugar')
plt.title('Distributiion of Residual Sugar')
plt.show()

# %%
plt.hist(df_wine['chlorides'], bins=30, color='orange', edgecolor='black')
plt.xlabel('chlorides')
plt.title('Distributiion of Chlorides')
plt.show()

# %%
plt.hist(df_wine['free sulfur dioxide'], bins=30, color='pink', edgecolor='black')
plt.xlabel('free sulfur dioxide')
plt.title('Distributiion of Free Sulfur Dioxide')
plt.show()

# %%
plt.hist(df_wine['total sulfur dioxide'], bins=30, color='red', edgecolor='black')
plt.xlabel('total sulfur dioxide')
plt.title('Distributiion of Total Sulfur Dioxide')
plt.show()

# %%
plt.hist(df_wine['density'], bins=30, color='purple', edgecolor='black')
plt.xlabel('density')
plt.title('Distributiion of Density')
plt.show()

# %%
plt.hist(df_wine['pH'], bins=30, color='brown', edgecolor='black')
plt.xlabel('pH')
plt.title('Distributiion of pH')
plt.show()

# %%
plt.hist(df_wine['sulphates'], bins=30, color='lime', edgecolor='black')
plt.xlabel('sulphates')
plt.title('Distributiion of Sulphates')
plt.show()

# %%
plt.hist(df_wine['alcohol'], bins=30, color='silver', edgecolor='black')
plt.xlabel('alcohol')
plt.title('Distributiion of Alcohol')
plt.show()

# %% [markdown]
# **What patterns or trends can you observe from the distributions? Are there any features with skewed
# distributions or outliers?**

# %%
features = [
    'fixed acidity', 'volatile acidity', 'residual sugar', 'chlorides',
    'free sulfur dioxide', 'total sulfur dioxide', 'density',
    'pH', 'sulphates', 'alcohol'
]
# Calculate skewness and kurtosis
skew_kurt = pd.DataFrame({
    'Feature': features,
    'Skewness': [df_wine[feature].skew() for feature in features],
    'Kurtosis': [df_wine[feature].kurtosis() for feature in features]
})
print(skew_kurt)
# Bar plot for skewness
plt.figure(figsize=(10, 5))
plt.bar(skew_kurt['Feature'], skew_kurt['Skewness'], color='darkblue', edgecolor='black')
plt.xticks(rotation=45)
plt.title('Skewness of Wine Features')
plt.axhline(0, color='black', linestyle='--', linewidth=1)
plt.ylabel('Skewness')
plt.tight_layout()
plt.show()
# Out:
#                 Feature  Skewness   Kurtosis
# 0         fixed acidity  0.982751   1.132143
# 1      volatile acidity  0.671593   1.225542
# 2        residual sugar  4.540655  28.617595
# 3             chlorides  5.680347  41.715787
# 4   free sulfur dioxide  1.250567   2.023562
# 5  total sulfur dioxide  1.515531   3.809824
# 6               density  0.071288   0.934079
# 7                    pH  0.193683   0.806943
# 8             sulphates  2.428672  11.720251
# 9               alcohol  0.860829   0.200029

# %% [markdown]
# **Task 2 : Task 2: Correlation Heatmap
# Goal: Visualize relationships between numerical features.
# Task:
# Create a correlation heatmap to visualize the correlations between the numerical variables.
# Highlight and discuss any strong positive or negative correlations, especially those that could influence
# wine quality. Which variables seem to be most closely related?**

# %%
numeric_columns = [ 'fixed acidity', 'volatile acidity', 'residual sugar', 'chlorides', 'free sulfur dioxide', 
                   'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol']
correlation = df_wine[numeric_columns].corr()
plt.figure(figsize=(7, 3))
sns.heatmap(correlation, annot=True, cmap='Reds', center=0)
plt.title('Correlation Heatmap of Red and White Wines')
plt.show()

# %% [markdown]
# **Task 3: Wine Quality vs Alcohol Content
# Goal: Explore the relationship between wine quality and alcohol content.
# Task:
# Create a boxplot that shows the distribution of alcohol across different quality ratings.
# What trends or patterns do you observe? Does higher alcohol content generally correlate with higher
# wine quality?**

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='quality', y='alcohol', hue='quality', data=df_wine)
plt.title('Wine Quality vs Alcohol Content')
plt.show()

# %% [markdown]
# **Task 4: Quality Distribution
# Goal: Understand the distribution of wine quality scores.
# Task:
# Use a countplot to visualize how wine quality is distributed (i.e., how often each quality score appears in
# the dataset).
# Which quality rating appears most frequently? Discuss the percentage of wines that have this common
# quality.**

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='quality', data=df_wine, hue='quality', palette='Set2')
plt.xlabel('Wine Quality Score')
plt.ylabel('Number of Wines')
plt.title('Distribution of Wine Quality Scores')
plt.show()

# %% [markdown]
# **Task 5: Visualizing Distribution of Key Variables with Boxplots and Histograms
# Goal: Explore relationships between wine quality and several key chemical features.
# Task:
# Visualize the distribution of key variables (alcohol, sulphates, citric acid, and fixed_acidity) with boxplots
# and histograms.
# What do you observe about how wine quality is related to these features? Are there any patterns that
# stand out? note: Create a subplot showing boxplots and histograms for each of the selected features
# (alcohol, sulphates, citric_acid, and fixed_acidity) with a title describing the feature being visualized.**

# %%
plt.figure(figsize=(18, 10))
selected_features = ['alcohol', 'sulphates', 'citric acid', 'fixed acidity']
# Loop through each feature and create a boxplot and histogram
for i, feature in enumerate(selected_features, 1):
    # Boxplot (subplot 1)
    plt.subplot(2, 4, i)  # 2 rows, 4 columns, feature position
    sns.boxplot(x=df_wine[feature])
    plt.title(f'Boxplot of {feature}')
    
    # Histogram (subplot 2)
    plt.subplot(2, 4, i+4)  # 2 rows, 4 columns, feature position (second row)
    sns.histplot(df_wine[feature], kde=True, bins=15, color='green')
    plt.title(f'Histogram of {feature}')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Task 6: Scatter Plot for Fixed Acidity vs Alcohol Content
# Goal: Investigate the relationship between acidity and alcohol content.
# Task:
# Create scatter plots to analyze the relationship between fixed_acidity and alcohol , as well as
# volatile_acidity and alcohol .
# Do you observe any trends or patterns? How do these variables appear to correlate with each other?**

# %%
plt.figure(figsize=(7, 5))
plt.subplot(1, 2, 1)
sns.scatterplot(x='fixed acidity', y='alcohol', data=df_wine, color='purple', alpha=0.6)
plt.title('Fixed Acidity vs Alcohol Content')
plt.xlabel('Fixed Acidity')
plt.ylabel('Alcohol (%)')

plt.subplot(1, 2, 2)
sns.scatterplot(x='volatile acidity', y='alcohol', data=df_wine, color='darkorange', alpha=0.6)
plt.title('Volatile Acidity vs Alcohol Content')
plt.xlabel('Volatile Acidity')
plt.ylabel('Alcohol (%)')
plt.show()

# %% [markdown]
# **Task 7: Impact of Sulfur Dioxide on Wine Quality
# Goal: Explore the impact of sulfur dioxide levels on wine quality.
# Task:
# Create scatter plots to show the relationship between free_sulfur_dioxide and quality , and
# between total_sulfur_dioxide and quality .
# between total_sulfur_dioxide and quality .
# How does the presence of sulfur dioxide seem to influence the quality rating of wine?**

# %%
plt.figure(figsize=(10, 6))
plt.subplot(1, 2, 1)
sns.scatterplot(x='free sulfur dioxide', y='quality', data=df_wine, color='green', alpha=0.6)
plt.title('free sulfur dioxide vs Quality')
plt.xlabel('quality')
#plt.xlabel('free sulfur dioxide')
plt.ylabel('free sulfur dioxide')
#plt.ylabel('quality')

plt.subplot(1, 2, 2)
sns.scatterplot(x='total sulfur dioxide', y='quality', data=df_wine, color='orange', alpha=0.6)
plt.title('total sulfur dioxide vs Quality')
plt.xlabel('quality')
#plt.xlabel('total sulfur dioxide')
plt.ylabel('total sulfur dioxide')
#plt.ylabel('quality')
plt.show()

# %% [markdown]
# **Task 8: Boxplot for Quality vs Various Features
# Goal: Explore the impact of several features on wine quality.
# Task:
# For each of the following features ( fixed_acidity , residual_sugar , sulphates , citric_acid ,
# density ), create a boxplot showing how the feature values vary across different wine quality ratings.
# Which features show the most variation across quality ratings? Are there clear patterns that indicate
# which features influence wine quality?**

# %%
features = ['fixed acidity', 'residual sugar', 'sulphates', 'citric acid', 'density']

# Set up the plot
plt.figure(figsize=(16, 18))

for idx, feature in enumerate(features, 1):
    plt.subplot(3, 2, idx)
    sns.boxplot(x='quality', y=feature, hue='quality', data=df_wine, palette='coolwarm')
    plt.title(f'{feature.capitalize()} vs Wine Quality')
    plt.xlabel('Wine Quality')
    plt.ylabel(feature.capitalize())

plt.tight_layout()
plt.show()

# %% [markdown]
# **Conclusion**

# %% [markdown]
# **Q1. Based on the boxplots, what do you observe about the relationship between wine quality and the following
# features:**

# %% [markdown]
# **1. Fixed Acidity
# Typical Trend: Little to moderate correlation with wine quality.
# Observation from Boxplots (usually): The median fixed acidity tends to be fairly consistent across quality levels, though higher quality wines might show slightly higher values.
# Conclusion: Not a strong determinant of quality on its own.**

# %% [markdown]
# **2. Residual Sugar
# Typical Trend: Weak or no clear correlation with quality.
# Observation from Boxplots: Higher quality wines don’t necessarily have more residual sugar; lower quality wines may show more variability and occasional outliers.
# Conclusion: High residual sugar doesn’t guarantee high quality.**

# %% [markdown]
# **3. Sulphates
# Typical Trend: Moderate positive correlation with quality.
# Observation from Boxplots: Higher quality wines generally have higher median sulphate levels, and the interquartile range shifts upward with quality.
# Conclusion: Sulphates can be a useful indicator of better wine quality.**

# %% [markdown]
# **Citric Acid
# Typical Trend: Positive correlation with wine quality.
# Observation from Boxplots: Wines rated higher often show increased citric acid levels, with a more tightly grouped distribution.
# Conclusion: Higher citric acid may contribute to perceived freshness and quality.**

# %% [markdown]
# **5. Density
# Typical Trend: Negative correlation with quality.
# Observation from Boxplots: Higher density is typically associated with lower quality wines.
# Conclusion: As sugar content and alcohol affect density, this could suggest over-sweetness or lower alcohol in lower quality wines.**

# %% [markdown]
# **Q2: Which feature seems to have the most noticeable impact on wine quality? Explain briefly.**
